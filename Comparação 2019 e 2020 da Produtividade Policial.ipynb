# %% [markdown]
# # Comparando a produtividade policial de SJC (19/20)
#
# * Comparando os atributos do dataset

# %%
#Importando as bibliotecas
import pandas as pd 
import numpy as np
import matplotlib as mat
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
sns.set(style="whitegrid")
sns.set_color_codes("pastel")

# %%
#Abrindo o dataset
df = pd.read_csv('https://raw.githubusercontent.com/Daniel-RPS/Produtividade-Policial-SJC/main/Produtividade%20Policial%20SJC.csv', sep=';', encoding='ISO-8859-1')
df.head()
# Out:
#     ANO        MÊS  OCORRÊNCIAS DE PORTE DE ENTORPECENTES  \
# 0  2019    JANEIRO                                      6
# 1  2019  FEVEREIRO                                     10
# 2  2019      MARÇO                                      6
# 3  2019      ABRIL                                      7
# 4  2019       MAIO                                     11
#
#    OCORRÊNCIAS DE TRÁFICO DE ENTORPECENTES  \
# 0                                       49
# 1                                       33
# 2                                       47
# 3                                       43
# 4                                       57
#
#    OCORRÊNCIAS DE APREENSÃO DE ENTORPECENTES(1)  \
# 0                                             1
# 1                                             0
# 2                                             3
# 3                                             1
# 4                                             0
#
# ...

# %%
#Nome das colunas
df.columns
# Out:
# Index(['ANO', 'MÊS', 'OCORRÊNCIAS DE PORTE DE ENTORPECENTES',
#        'OCORRÊNCIAS DE TRÁFICO DE ENTORPECENTES',
#        'OCORRÊNCIAS DE APREENSÃO DE ENTORPECENTES(1)',
#        'OCORRÊNCIAS DE PORTE ILEGAL DE ARMA',
#        'Nº DE ARMAS DE FOGO APREENDIDAS', 'Nº DE FLAGRANTES LAVRADOS',
#        'Nº DE INFRATORES APREENDIDOS EM FLAGRANTE',
#        'Nº DE INFRATORES APREENDIDOS POR MANDADO',
#        'Nº DE PESSOAS PRESAS EM FLAGRANTE', 'Nº DE PESSOAS PRESAS POR MANDADO',
#        'Nº DE PRISÕES EFETUADAS', 'Nº DE VEÍCULOS RECUPERADOS',
#        'TOT. DE INQUÉRITOS POLICIAIS INSTAURADOS'],
#       dtype='object')

# %%
#Função para plotar os gráficos

def graficos(y):
    g = sns.factorplot(x="MÊS",y=y, 
                       hue="ANO", data=df, size=7, kind="bar", palette="muted")
    g.despine(left=True)
    plt.xticks(rotation = 90);
    plt.show()

# %% [markdown]
# ### 1 - OCORRÊNCIAS DE PORTE DE ENTORPECENTES
#
# * Em 2019, o pico de ocorrências de porte de entorpecentes foi em Maio. Em 2020, o pico foi em Dezembro

# %%
graficos("OCORRÊNCIAS DE PORTE DE ENTORPECENTES")

# %% [markdown]
# ### 2 - OCORRÊNCIAS DE TRÁFICO DE ENTORPECENTES
#
# * Em 2019, o pico de ocorrências de tráfico de entorpecentes foi em Novembro. Em 2020, o pico foi em Março

# %%
graficos("OCORRÊNCIAS DE TRÁFICO DE ENTORPECENTES")

# %% [markdown]
# ### 3 - OCORRÊNCIAS DE APREENSÃO DE ENTORPECENTES
#
# * Em 2019, o pico de ocorrências de apreensão de entorpecentes foi em Março. Em 2020, Janeiro e Março foram os meses que mais registraram casos.

# %%
graficos('OCORRÊNCIAS DE APREENSÃO DE ENTORPECENTES(1)')

# %% [markdown]
# ### 4 - OCORRÊNCIAS DE PORTE ILEGAL DE ARMA
#
# * Tanto em 2019 quanto em 2020, o pico de ocorrências de porte ilegal de arma foi no mês de Março.

# %%
graficos("OCORRÊNCIAS DE PORTE ILEGAL DE ARMA")

# %% [markdown]
# ### 5 - Nº DE ARMAS DE FOGO APREENDIDAS
#
# * Tanto em 2019 quanto em 2020, o pico de armas de fogo apreendidas foi no mês de Outubro.

# %%
graficos("Nº DE ARMAS DE FOGO APREENDIDAS")

# %% [markdown]
# ### 6 - Nº DE FLAGRANTES LAVRADOS
#
# * Em 2019, o pico de ocorrências de flagrantes lavrados foi em Março. Em 2020, o pico foi em Setembro.

# %%
graficos("Nº DE FLAGRANTES LAVRADOS")

# %% [markdown]
# ### 7 - Nº DE INFRATORES APREENDIDOS EM FLAGRANTE
#
# * Em 2019, o pico de infratores apreendidos em flagrante foi em Setembro. Em 2020, o pico foi em Junho.

# %%
graficos("Nº DE INFRATORES APREENDIDOS EM FLAGRANTE")

# %% [markdown]
# ### 8 - Nº DE INFRATORES APREENDIDOS POR MANDADO
#
# * Em 2019, o pico de nº de infratores apreendidos por mandado foi em Março. Em 2020, o pico foi em Janeiro.

# %%
graficos("Nº DE INFRATORES APREENDIDOS POR MANDADO")

# %% [markdown]
# ### 9 - Nº DE PESSOAS PRESAS EM FLAGRANTE
#
# * Em 2019, o pico de pessoas presas em flagrante ocorreu em Setembro. Em 2020, o pico foi em Junho.

# %%
graficos("Nº DE PESSOAS PRESAS EM FLAGRANTE")

# %% [markdown]
# ### 10 - Nº DE PESSOAS PRESAS POR MANDADO
#
# * Em 2019, o pico de pessoas presas por mandado foi em Julho. Em 2020, o pico foi em Janeiro.

# %%
graficos("Nº DE PESSOAS PRESAS POR MANDADO")

# %% [markdown]
# ### 11 - Nº DE PRISÕES EFETUADAS
#
# * Em 2019, o pico de prisões efetuadas foi em Setembro. Em 2020, o pico foi em Março.

# %%
graficos("Nº DE PRISÕES EFETUADAS")

# %% [markdown]
# ### 12 - Nº DE VEÍCULOS RECUPERADOS
#
# * Em 2019, o pico de veículos recuperados foi em Junho. Em 2020, o pico ocorreu em Janeiro.

# %%
graficos("Nº DE VEÍCULOS RECUPERADOS")

# %% [markdown]
# ### 13 - TOT. DE INQUÉRITOS POLICIAIS INSTAURADOS
#
# * Tanto em 2019 quanto em 2020, o pico de ocorrências de inquéritos totais instaurados foi no mês de Setembro.

# %%
graficos("TOT. DE INQUÉRITOS POLICIAIS INSTAURADOS")
